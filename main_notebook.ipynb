# %%
import pandas as pd 
import matplotlib as plt

# %%
from Modelling import plotting_ml as pm

# %%
local = 'Data/data_plot_ml.csv'
local_output = 'Data/plots'

# %%
pm.plot_ml(local)

# %%
pm.plot_ml_save(local, local_output)
